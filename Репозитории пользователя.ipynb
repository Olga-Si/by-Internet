# %%
pip install PyGithub requests #для удобства устанавливаем библиотеки PyGithub

# %%
import base64
from github import Github
from pprint import pprint
username = "Olga-Si" # Указываем имя пользователя, чьи репозитории хотим посмотреть (открытые)
g = Github()
user = g.get_user(username)
for repo in user.get_repos():
    print(repo)
# Out:
# Repository(full_name="Olga-Si/Python")
